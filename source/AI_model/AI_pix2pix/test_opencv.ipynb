# %%
import numpy as np
import imageio
import scipy.ndimage
import cv2
from IPython.display import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import imageio
#       3 import scipy.ndimage
#       4 import cv2
#
# ModuleNotFoundError: No module named 'imageio'

# %%
# !dir
# Out:
# checkpoint     im_test_edge2.png  Model.png    __pycache__    test.ipynb
# dataloader.py  im_test.jpg	  mymodels.py  README.md      train.ipynb
# dataset        Model_details.pdf  outputs      test_image_bd  Untitled.ipynb

# %%
im = "im_bd.jpg"

# %%
def grayscale(rgb):
	return np.dot(rgb[...,:3],[0.299,0.587,0.114])

# %%
def dodge(front,back):
	result=front*255/(255-back)
	result[result>255]=255
	result[back==255]=255
	return result.astype('uint8')

# %%
s=imageio.imread(im)
g=grayscale(s)
i=255-g

b=scipy.ndimage.filters.gaussian_filter(i,sigma=10)
r=dodge(b,g)

cv2.imwrite('im_test_edge.png',r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s=imageio.imread(im)
#       2 g=grayscale(s)
#       3 i=255-g
#
# NameError: name 'imageio' is not defined

# %%
from IPython.display import Image
Image(filename='im_test.jpg')

# %%
Image(filename='im_test_edge.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Image(filename='im_test_edge.png')
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: 'im_test_edge.png'

# %%
average = r.mean(axis=0).mean(axis=0)
print(average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 average = r.mean(axis=0).mean(axis=0)
#       2 print(average)
#
# NameError: name 'r' is not defined

# %%
img = cv2.imread("im_test.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 img = cv2.imread("im_test.jpg")
#
# NameError: name 'cv2' is not defined

# %%
grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
invert = cv2.bitwise_not(grey_img)
blur = cv2.GaussianBlur(invert, (21,21),0)
invertedblur = cv2.bitwise_not(blur)
sketch = cv2.divide(grey_img, invertedblur, scale=256.0)

# %%
cv2.imwrite('im_test_edge2.png',sketch)
# Out:
# True

# %%
from IPython.display import Image
Image(filename='im_test_edge2.png')

# %%
average = sketch.mean(axis=0).mean(axis=0)
print(average)
# Out:
# 238.58590265388048

# %%
import os
folder_path = "./test_image_bd"
for path,dirs, files in os.walk(folder_path):
    for filename in files:
        print(filename)
# Out:
# im_test.jpg
# im_bd.jpg
# m.png
# im_test_bd3.jpg
# im_test_bd.jpg

# %%
def Color2Sketch(img):
    grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    invert = cv2.bitwise_not(grey_img)
    blur = cv2.GaussianBlur(invert, (21,21),0)
    invertedblur = cv2.bitwise_not(blur)
    sketch = cv2.divide(grey_img, invertedblur, scale=256.0)
    return sketch

# %%
import os
import cv2
folder_path = "./test_image_bd/m.png"
img = cv2.imread(folder_path)
dimensions = img.shape
sketch = Color2Sketch(img)
cv2.imwrite('my_sketch.png',sketch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       4 img = cv2.imread(folder_path)
#       5 dimensions = img.shape
# ----> 6 sketch = Color2Sketch(img)
#       7 cv2.imwrite('my_sketch.png',sketch)
#
# NameError: name 'Color2Sketch' is not defined

# %%
from IPython.display import Image
Image(filename='my_sketch.png')
